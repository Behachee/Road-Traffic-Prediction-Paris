# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('comptages-routiers-permanents.csv', delimiter = ';') # do we want older or more recent data ?

# %%
traffic = data.copy()
traffic
# Out:
#           Identifiant arc                Libelle  Date et heure de comptage  \
# 0                    5356        PI_Menilmontant  2022-11-02T12:00:00+01:00
# 1                    4807        Av_des_Gobelins  2022-12-06T18:00:00+01:00
# 2                    1416            Av_Gambetta  2023-01-08T09:00:00+01:00
# 3                    4251            Bd_Berthier  2023-02-02T00:00:00+01:00
# 4                    4898         Av_Jean_Jaures  2023-03-09T19:00:00+01:00
# ...                   ...                    ...                        ...
# 21719596             5582               Lecourbe  2023-10-24T10:00:00+02:00
# 21719597             1698                 Bd_Ney  2023-11-24T07:00:00+01:00
# 21719598             5236  PE_Cite_Universitaire  2022-11-14T11:00:00+01:00
# 21719599             4992                Tolbiac  2022-12-25T17:00:00+01:00
# 21719600              424         Quai_Tournelle  2023-01-25T00:00:00+01:00
#
# ...

# %%
amont = traffic[traffic["Libelle noeud amont"].isin(['Av_Champs_Elysees-Washington', "Convention-Blomet", "Sts_Peres-Voltaire"])]
df = amont[amont["Libelle noeud aval"].isin(['Av_Champs_Elysees-Berri', "Lecourbe-Convention", "Sts_Peres-Universite"]) ]
df
# Out:
#           Identifiant arc            Libelle  Date et heure de comptage  \
# 7953                 4264  AV_Champs_Elysees  2023-02-01T23:00:00+01:00
# 7979                 4264  AV_Champs_Elysees  2023-02-01T22:00:00+01:00
# 8006                 4264  AV_Champs_Elysees  2023-02-01T20:00:00+01:00
# 8030                 4264  AV_Champs_Elysees  2023-02-01T18:00:00+01:00
# 9790                  191          Sts_Peres  2023-08-10T00:00:00+02:00
# ...                   ...                ...                        ...
# 21713553              191          Sts_Peres  2023-01-24T18:00:00+01:00
# 21718370             5672         Convention  2023-02-15T11:00:00+01:00
# 21718482              191          Sts_Peres  2023-01-25T00:00:00+01:00
# 21718508              191          Sts_Peres  2023-01-24T23:00:00+01:00
# 21718533              191          Sts_Peres  2023-01-24T19:00:00+01:00
#
#           Débit horaire  Taux d'occupation Etat trafic  \
# ...

# %%
df.to_csv('donnée_dash.csv', index=False)
